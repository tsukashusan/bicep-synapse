# %% [markdown]
# # Spark SQL + サーバーレス
#
# ## データベースの作成

# %%
from pyspark.sql import SparkSession

abfs_account_name = 'storageonpm2zh5xs2xa' # replace with your storage account name
abfs_container_name = 'dl2' # replace with your container name
linked_service_name = 'synapseonpm2zh5xs2xa-WorkspaceDefaultStorage' # replace with your linked service name

spark.sql("CREATE DATABASE `hanbaikanri`")
# Out:
# AnalysisException : org.apache.hadoop.hive.metastore.api.AlreadyExistsException: Database hanbaikanri already exists;
# Traceback (most recent call last):
#
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py", line 649, in sql
#     return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#
#   File "/home/trusted-service-user/cluster-env/env/lib/python3.6/site-packages/py4j/java_gateway.py", line 1305, in __call__
#     answer, self.gateway_client, self.target_id, self.name)
#
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/sql/utils.py", line 134, in deco
#     raise_from(converted)
#
#   File "<string>", line 3, in raise_from
#
# pyspark.sql.utils.AnalysisException: org.apache.hadoop.hive.metastore.api.AlreadyExistsException: Database hanbaikanri already exists;

# %%
# spark.sql("DROP DATABASE `hanbaikanri`")
# Out:
# DataFrame[]

# %% [markdown]
# ## 仕入先テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.shiiresaki
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/shiiresaki/"
    ''' % abfs_account_name)
# Out:
# AnalysisException : Table hanbaikanri.shiiresaki already exists.;
# Traceback (most recent call last):
#
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/sql/session.py", line 649, in sql
#     return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#
#   File "/home/trusted-service-user/cluster-env/env/lib/python3.6/site-packages/py4j/java_gateway.py", line 1305, in __call__
#     answer, self.gateway_client, self.target_id, self.name)
#
#   File "/opt/spark/python/lib/pyspark.zip/pyspark/sql/utils.py", line 134, in deco
#     raise_from(converted)
#
#   File "<string>", line 3, in raise_from
#
# pyspark.sql.utils.AnalysisException: Table hanbaikanri.shiiresaki already exists.;

# %% [markdown]
# ## 社員テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.shain
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/shain/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 都道府県テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.todofuken
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/todofuken/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 商品テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.shohin
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/shohin/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 商品区分テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.shohinkubun
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/shohinkubun/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 得意先テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.tokuisaki
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/tokuisaki/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 運送テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.unso
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/unso/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 受注テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.zyuchu
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/zyuchu/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %% [markdown]
# ## 受注明細テーブル作成

# %%
spark.sql('''CREATE TABLE hanbaikanri.zyuchumeisai
    USING Parquet
    LOCATION "abfss://dl2@%s.dfs.core.windows.net/parquet/zyuchumeisai/"
    ''' % abfs_account_name)
# Out:
# DataFrame[]

# %%
# %%sql
#
# SELECT * FROM hanbaikanri.shiiresaki
